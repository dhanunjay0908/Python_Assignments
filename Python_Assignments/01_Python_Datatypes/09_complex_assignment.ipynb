# %% [markdown]
# Complex Assignment

# %%
# Question 1: Create complex number 5 + 3j

complex_ = 5+3j

# %%
# Question 2: Find the real part of complex number 7 - 2j

complex_ = 7-2j
print(complex_.real)
# Out:
# 7.0

# %%
# Question 3: Find the imaginary part of complex number 4 + 6j

complex_ = 4+6j
print(complex_.imag)
# Out:
# 6.0

# %%
# Question 4: Add two complex numbers: (3 + 2j) and (1 + 4j)

complex1 = 3+2j
complex2 = 1+4j
adding = complex1+complex2
print(adding)
# Out:
# (4+6j)

# %%
# Question 5: Multiply two complex numbers: (2 + 3j) and (1 + 2j)

complex1 = 2+3j
complex2 = 1+2j
product = (complex1 * complex2)
print(product)
# Out:
# (-4+7j)

# %%
# Question 6: Find the magnitude of complex number 6 + 8j

# formula : sqrt(a**2 + b**2)
import math
complex_ = 6+8j
magnitude = math.sqrt(complex_.real**2 + complex_.imag**2)
print(magnitude)
# Out:
# 10.0

# %%
# Question 7: Find the conjugate of complex number 5 - 7j

complex_ = 5-7j
conjugate = complex(complex_.real, -complex_.imag)
print(conjugate)

# using conjugate() built-in
print(complex_.conjugate())
# Out:
# (5+7j)
# (5+7j)

# %%
# Question 8: Subtract complex numbers: (10 + 5j) - (3 + 2j)

complex1 = (10 + 5j)
complex2 = (3 + 2j)
sub = complex1 - complex2
print(sub)
# Out:
# (7+3j)

# %%
# Question 9: Divide complex numbers: (8 + 6j) / (2 + 1j)

complex1 = (8 + 6j)
complex2 = (2 + 1j)
div = complex1/complex2
print(div)
# Out:
# (4.4+0.8j)

# %%
# Question 10: Find the phase angle of complex number 1 + 1j

complex_ = 1+1j
phase_angle = math.atan2(complex_.imag, complex_.real)
print(phase_angle)

# using phase() built-in
import cmath
print(cmath.phase(complex_))
# Out:
# 0.7853981633974483
# 0.7853981633974483
